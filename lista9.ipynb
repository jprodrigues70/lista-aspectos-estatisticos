# %% [markdown]
# ## Questão 9
# ### Letra A

# %%
a <- c(33,38,36,40,31,35)
b <- c(32,40,42,38,30,34)
c <- c(31,37,35,33,34,30)
d <- c(28,34,32,30,33,31)

# %%
boxplot(a,b,c,d, names=c('A', 'B','C','D'))
# Out:
# plot without title
