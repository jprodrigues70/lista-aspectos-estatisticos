# %% [markdown]
# ## Questão 10
# ### Letras A e B

# %%
x <- c(0,0,2,3,4,4,5,7)
y <- c(2,3,2,5,9,8,8,15)
c = cor.test(x, y, method = c("pearson"))
print(c)
# Out:
# 	Pearson's product-moment correlation
#
# data:  x and y
# t = 5.9798, df = 6, p-value = 0.0009818
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.6343472 0.9866595
# sample estimates:
#       cor
# 0.9253721

# %% [markdown]
# #### Logo, há correlação positiva forte entre as variáveis

# %% [markdown]
# ### Letra C

# %%
linearR = lm(y ~ x)
linearR
# Out:
# Call:
# lm(formula = y ~ x)
#
# Coefficients:
# (Intercept)            x
#       1.187        1.700

# %% [markdown]
# ### Letra D

# %%
plot(x, y, abline(linearR))
# Out:
# plot without title
