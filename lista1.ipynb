# %% [markdown]
# ## Questão 1

# %%
x = runif(3000)
y = runif(3000)
z = x + y

# %%
hist(x)
hist(y)
hist(z)
# Out:
# Plot with title “Histogram of x”
# Plot with title “Histogram of y”
# Plot with title “Histogram of z”

# %%
beta = rbeta(1000,4,5)
hist(beta)
# Out:
# Plot with title “Histogram of beta”

# %%
logis = rlogis(1000)
hist(logis)
# Out:
# Plot with title “Histogram of logis”

# %%
y = seq()
for (x in 0:1000){
    x1 = runif(1)
    x2 = runif(1)
    y_norm = sqrt((-2)*log(x1))* cos(2*pi*x2)
    y[x] <- y_norm
}
hist(y)
# Out:
# Plot with title “Histogram of y”
